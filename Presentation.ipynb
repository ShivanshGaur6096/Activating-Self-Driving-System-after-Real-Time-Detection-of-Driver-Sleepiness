# %% [markdown]
# # Driver Sleepiness Detection

# %%
import numpy as np

# %% [markdown]
# #### NumPy
# Provides:
# 1. An array object of arbitrary homogeneous items
# 2. Fast mathematical operations over arrays
# 3. Linear Algebra, Fourier Transforms, Random Number Generation

# %%
from scipy.spatial import distance

# %% [markdown]
# #### Scipy
# 1. We are using sub-module "Spatial" which was mainly used for the 'Algorithms and Data Structures'.
# 2. In spatial Distance matrics are contain which we used for "Nearest-neighbor Queries".
#     Basically to classify the image falling in sleepiness category or not by using Distace formula

# %%
from imutils import face_utils

# %% [markdown]
# #### Imutils
# It's a series of Convenience function to make a basic image processing functions and displaying images easier with OpenCV and Python. Some image functions like:
# 1. Translation: Moving image in any direction,
# 2. Rotation: Rotating image in horizontal, vertical, or their flipped position,
# 3. Resizing: Resizingthe vindow to display the image. It is really important while you are testing as there is limited screen size and you need to fit every window in front of you. ![image.png](attachment:image.png)

# %%
import dlib

# %% [markdown]
# #### DLIB
# 1. Modern C++ toolkit containing ML Algo. and tools
# 2. Mostly used for creating complex software to solve real world problems
# 3. We can have .dat file which contain 68 facial landmarks. But to increase efficiency in prediction by 8-10% and decrease the size of file to 98MB we created minimized the landmarks for 20 which is best for our system to detect eyes and nose mainly.

# %%
import cv2

# %% [markdown]
# #### OpenCV (cv2)
# 1. CV represents Computer Vesion
# 2. Designed to focus on real-time application for computational efficency.
# 3. Collect important "Features from Image" by applying different image processing features.
# 3. It is written in optimized C/C++ to take advantage of multi-core processing and it is compatable with Python.
# 3. Majorly used in Self-Driving Car, Robotics as well as in Photo Correction App
